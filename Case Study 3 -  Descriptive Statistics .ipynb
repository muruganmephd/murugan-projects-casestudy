# %% [markdown]
# # Descriptive Statistics Case Study

# %%
import pandas as pd
data=pd.read_csv('country_profile_variables.csv')
data
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                                20270
# 1                                                11541
# 2                                               164779
# 3                                                  -99
# 4                                                 2812
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                              29688
# 227                                              21255
# 228                                              13893
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                           -99.0                             -99  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                         -99.0                             -99  ...
# 225                         -99.0                             -99  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                  -99
# 4                                                 96.9
# ..                                                 ...
# 224                                                9.0
# 225                                                -99
# 226                                               25.1
# 227                                               21.0
# 228                                               16.4
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 0                                                   42
# 1                                                  130
# 2                                                  135
# 3                                                   92
# 4                                                   13
# ..                                                 ...
# 224                                                 89
# 225                                                 49
# 226                                                298
# 227                                                 88
# 228                                                 89
#
#     Threatened species (number) Forested area (% of land area)  \
# 0                           2.1                        9.8/0.3
# 1                          28.2                        5.7/2.0
# 2                           0.8                      145.4/3.7
# 3                          87.9                            -99
# 4                          34.0                        0.5/6.4
# ..                          ...                            ...
# 224                        41.6                       ~0.0/1.6
# 225                         2.7                            -99
# 226                         1.0                       22.7/0.9
# 227                        65.6                        4.5/0.3
# 228                        37.2                       12.0/0.8
#
#     CO2 emission estimates (million tons/tons per capita)  \
# 0                                                   63
# 1                                                   84
# 2                                                 5900
# 3                                                  -99
# 4                                                    1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                668
# 227                                                374
# 228                                                482
#
#     Energy production, primary (Petajoules)  \
# 0                                         5
# 1                                        36
# 2                                        55
# 3                                       -99
# 4                                       119
# ..                                      ...
# 224                                      26
# 225                                     -99
# 226                                      12
# 227                                      26
# 228                                      30
#
#     Energy supply per capita (Gigajoules)  \
# 0                               78.2/47.0
# 1                               94.9/95.2
# 2                               84.3/81.8
# 3                             100.0/100.0
# 4                             100.0/100.0
# ..                                    ...
# 224                                   -99
# 225                                   -99
# 226                             72.0/46.5
# 227                             85.6/51.3
# 228                             97.0/67.3
#
#      Pop. using improved drinking water (urban/rural, %)  \
# 0                                            45.1/27.0
# 1                                            95.5/90.2
# 2                                            89.8/82.2
# 3                                            62.5/62.5
# 4                                          100.0/100.0
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                          92.5/34.1
# 227                                          55.6/35.7
# 228                                          49.3/30.8
#
#      Pop. using improved sanitation facilities (urban/rural, %)  \
# 0                                                21.43
# 1                                                 2.96
# 2                                                 0.05
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               2.99
# 227                                               3.96
# 228                                               6.00
#
#     Net Official Development Assist. received (% of GNI)
# 0                                                  -99
# 1                                                  -99
# 2                                                  -99
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                -99
# 227                                                -99
# 228                                                -99
#
# [229 rows x 50 columns]

# %%
data.isnull().sum()
# Out:
# country                                                       0
# Region                                                        0
# Surface area (km2)                                            0
# Population in thousands (2017)                                0
# Population density (per km2, 2017)                            0
# Sex ratio (m per 100 f, 2017)                                 0
# GDP: Gross domestic product (million current US$)             0
# GDP growth rate (annual %, const. 2005 prices)                0
# GDP per capita (current US$)                                  0
# Economy: Agriculture (% of GVA)                               0
# Economy: Industry (% of GVA)                                  0
# Economy: Services and other activity (% of GVA)               0
# Employment: Agriculture (% of employed)                       0
# Employment: Industry (% of employed)                          0
# Employment: Services (% of employed)                          0
# Unemployment (% of labour force)                              0
# Labour force participation (female/male pop. %)               0
# Agricultural production index (2004-2006=100)                 0
# Food production index (2004-2006=100)                         0
# International trade: Exports (million US$)                    0
# International trade: Imports (million US$)                    0
# International trade: Balance (million US$)                    0
# Balance of payments, current account (million US$)            0
# Population growth rate (average annual %)                     0
# Urban population (% of total population)                      0
# Urban population growth rate (average annual %)               0
# Fertility rate, total (live births per woman)                 0
# Life expectancy at birth (females/males, years)               0
# Population age distribution (0-14 / 60+ years, %)             0
# International migrant stock (000/% of total pop.)             0
# Refugees and others of concern to UNHCR (in thousands)        0
# Infant mortality rate (per 1000 live births                   0
# Health: Total expenditure (% of GDP)                          0
# Health: Physicians (per 1000 pop.)                            0
# Education: Government expenditure (% of GDP)                  0
# Education: Primary gross enrol. ratio (f/m per 100 pop.)      0
# Education: Secondary gross enrol. ratio (f/m per 100 pop.)    0
# Education: Tertiary gross enrol. ratio (f/m per 100 pop.)     0
# Seats held by women in national parliaments %                 0
# Mobile-cellular subscriptions (per 100 inhabitants)           0
# Mobile-cellular subscriptions (per 100 inhabitants).1         0
# Individuals using the Internet (per 100 inhabitants)          0
# Threatened species (number)                                   0
# Forested area (% of land area)                                0
# CO2 emission estimates (million tons/tons per capita)         0
# Energy production, primary (Petajoules)                       0
# Energy supply per capita (Gigajoules)                         0
# Pop. using improved drinking water (urban/rural, %)           0
# Pop. using improved sanitation facilities (urban/rural, %)    0
# Net Official Development Assist. received (% of GNI)          0
# dtype: int64

# %%
data.isna().sum()
# Out:
# country                                                       0
# Region                                                        0
# Surface area (km2)                                            0
# Population in thousands (2017)                                0
# Population density (per km2, 2017)                            0
# Sex ratio (m per 100 f, 2017)                                 0
# GDP: Gross domestic product (million current US$)             0
# GDP growth rate (annual %, const. 2005 prices)                0
# GDP per capita (current US$)                                  0
# Economy: Agriculture (% of GVA)                               0
# Economy: Industry (% of GVA)                                  0
# Economy: Services and other activity (% of GVA)               0
# Employment: Agriculture (% of employed)                       0
# Employment: Industry (% of employed)                          0
# Employment: Services (% of employed)                          0
# Unemployment (% of labour force)                              0
# Labour force participation (female/male pop. %)               0
# Agricultural production index (2004-2006=100)                 0
# Food production index (2004-2006=100)                         0
# International trade: Exports (million US$)                    0
# International trade: Imports (million US$)                    0
# International trade: Balance (million US$)                    0
# Balance of payments, current account (million US$)            0
# Population growth rate (average annual %)                     0
# Urban population (% of total population)                      0
# Urban population growth rate (average annual %)               0
# Fertility rate, total (live births per woman)                 0
# Life expectancy at birth (females/males, years)               0
# Population age distribution (0-14 / 60+ years, %)             0
# International migrant stock (000/% of total pop.)             0
# Refugees and others of concern to UNHCR (in thousands)        0
# Infant mortality rate (per 1000 live births                   0
# Health: Total expenditure (% of GDP)                          0
# Health: Physicians (per 1000 pop.)                            0
# Education: Government expenditure (% of GDP)                  0
# Education: Primary gross enrol. ratio (f/m per 100 pop.)      0
# Education: Secondary gross enrol. ratio (f/m per 100 pop.)    0
# Education: Tertiary gross enrol. ratio (f/m per 100 pop.)     0
# Seats held by women in national parliaments %                 0
# Mobile-cellular subscriptions (per 100 inhabitants)           0
# Mobile-cellular subscriptions (per 100 inhabitants).1         0
# Individuals using the Internet (per 100 inhabitants)          0
# Threatened species (number)                                   0
# Forested area (% of land area)                                0
# CO2 emission estimates (million tons/tons per capita)         0
# Energy production, primary (Petajoules)                       0
# Energy supply per capita (Gigajoules)                         0
# Pop. using improved drinking water (urban/rural, %)           0
# Pop. using improved sanitation facilities (urban/rural, %)    0
# Net Official Development Assist. received (% of GNI)          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna()
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# 1                              2930                               106.9
# 2                             41318                                17.3
# 3                                56                               278.2
# 4                                77                               163.8
# ..                              ...                                 ...
# 224                              12                                84.1
# 225                             553                                 2.1
# 226                           28250                                53.5
# 227                           17094                                23.0
# 228                           16530                                42.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 0                            106.3
# 1                            101.9
# 2                            102.0
# 3                            103.6
# 4                            102.3
# ..                             ...
# 224                           93.4
# 225                          110.1
# 226                          102.1
# 227                           98.5
# 228                           95.0
#
#      GDP: Gross domestic product (million current US$)  \
# 0                                                20270
# 1                                                11541
# 2                                               164779
# 3                                                  -99
# 4                                                 2812
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                              29688
# 227                                              21255
# 228                                              13893
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 0                                             -2.4
# 1                                              2.6
# 2                                              3.8
# 3                                              -99
# 4                                              0.8
# ..                                             ...
# 224                                            -99
# 225                                            -99
# 226                                          -28.1
# 227                                            2.9
# 228                                            1.1
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 0                           623.2                            23.3  ...
# 1                          3984.2                            22.4  ...
# 2                          4154.1                            12.2  ...
# 3                           -99.0                             -99  ...
# 4                         39896.4                             0.5  ...
# ..                            ...                             ...  ...
# 224                         -99.0                             -99  ...
# 225                         -99.0                             -99  ...
# 226                        1106.4                            14.7  ...
# 227                        1311.1                             8.2  ...
# 228                         890.4                            13.0  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                  8.3
# 1                                                 63.3
# 2                                                 38.2
# 3                                                  -99
# 4                                                 96.9
# ..                                                 ...
# 224                                                9.0
# 225                                                -99
# 226                                               25.1
# 227                                               21.0
# 228                                               16.4
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 0                                                   42
# 1                                                  130
# 2                                                  135
# 3                                                   92
# 4                                                   13
# ..                                                 ...
# 224                                                 89
# 225                                                 49
# 226                                                298
# 227                                                 88
# 228                                                 89
#
#     Threatened species (number) Forested area (% of land area)  \
# 0                           2.1                        9.8/0.3
# 1                          28.2                        5.7/2.0
# 2                           0.8                      145.4/3.7
# 3                          87.9                            -99
# 4                          34.0                        0.5/6.4
# ..                          ...                            ...
# 224                        41.6                       ~0.0/1.6
# 225                         2.7                            -99
# 226                         1.0                       22.7/0.9
# 227                        65.6                        4.5/0.3
# 228                        37.2                       12.0/0.8
#
#     CO2 emission estimates (million tons/tons per capita)  \
# 0                                                   63
# 1                                                   84
# 2                                                 5900
# 3                                                  -99
# 4                                                    1
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                668
# 227                                                374
# 228                                                482
#
#     Energy production, primary (Petajoules)  \
# 0                                         5
# 1                                        36
# 2                                        55
# 3                                       -99
# 4                                       119
# ..                                      ...
# 224                                      26
# 225                                     -99
# 226                                      12
# 227                                      26
# 228                                      30
#
#     Energy supply per capita (Gigajoules)  \
# 0                               78.2/47.0
# 1                               94.9/95.2
# 2                               84.3/81.8
# 3                             100.0/100.0
# 4                             100.0/100.0
# ..                                    ...
# 224                                   -99
# 225                                   -99
# 226                             72.0/46.5
# 227                             85.6/51.3
# 228                             97.0/67.3
#
#      Pop. using improved drinking water (urban/rural, %)  \
# 0                                            45.1/27.0
# 1                                            95.5/90.2
# 2                                            89.8/82.2
# 3                                            62.5/62.5
# 4                                          100.0/100.0
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                          92.5/34.1
# 227                                          55.6/35.7
# 228                                          49.3/30.8
#
#      Pop. using improved sanitation facilities (urban/rural, %)  \
# 0                                                21.43
# 1                                                 2.96
# 2                                                 0.05
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                               2.99
# 227                                               3.96
# 228                                               6.00
#
#     Net Official Development Assist. received (% of GNI)
# 0                                                  -99
# 1                                                  -99
# 2                                                  -99
# 3                                                  -99
# 4                                                  -99
# ..                                                 ...
# 224                                                -99
# 225                                                -99
# 226                                                -99
# 227                                                -99
# 228                                                -99
#
# [229 rows x 50 columns]

# %% [raw]
# For our analysis, we will choose a 'Population in thousands (2017)' column. We can perform the similar operations on other columns as well. We will get the measure of central tendency and measure of spread of the data.

# %%
data['Population in thousands (2017)'].mean()
# Out:
# 32756.794759825327

# %%
data['Population in thousands (2017)'].median()
# Out:
# 5448.0

# %%
data['Population in thousands (2017)'].mode()
# Out:
# 0        1
# 1       11
# 2       35
# 3       55
# 4       56
# 5      105
# 6      108
# 7      276
# 8      283
# 9     2890
# 10    2930
# Name: Population in thousands (2017), dtype: int64

# %%
data['Population in thousands (2017)'].max()-data['Population in thousands (2017)'].min()   # range
# Out:
# 1409516

# %%
data['Population in thousands (2017)'].std()
# Out:
# 133275.07991351312

# %%
data['Population in thousands (2017)'].var()
# Out:
# 17762246925.953312

# %%
import numpy as np
twe=np.percentile(data['Population in thousands (2017)'],25)
fif=np.percentile(data['Population in thousands (2017)'],50)
sev=np.percentile(data['Population in thousands (2017)'],75)
print(twe,fif,sev)
# Out:
# 431.0 5448.0 19193.0

# %%
Q1=data['Population in thousands (2017)'].quantile(0.25)
Q2=data['Population in thousands (2017)'].quantile(0.50)
Q3=data['Population in thousands (2017)'].quantile(0.75)
print(Q1,Q2,Q3)
# Out:
# 431.0 5448.0 19193.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 18762.0

# %%
UL=Q3+1.5*IQR
UL
# Out:
# 47336.0

# %%
LL=Q1-1.5*IQR
LL
# Out:
# -27712.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.hist(data['Population in thousands (2017)'])
# Out:
# (array([220.,   6.,   1.,   0.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([1.0000000e+00, 1.4095260e+05, 2.8190420e+05, 4.2285580e+05,
#         5.6380740e+05, 7.0475900e+05, 8.4571060e+05, 9.8666220e+05,
#         1.1276138e+06, 1.2685654e+06, 1.4095170e+06]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(data['Population in thousands (2017)'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Population in thousands (2017)', ylabel='Density'>

# %%
# This distribution is Right Skewed distribution curve.

# %% [raw]
# What is the probability that the Population in thousands(2017) is more than 50,000 given that
# Population density (per km2, 2017) is 100.0 or more?

# %%
data['Population']=np.where(data['Population in thousands (2017)']>50000,1,0)      # 1 stands for >50000, 0 stands for <50000

# %%
data['Population']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 224    0
# 225    0
# 226    0
# 227    0
# 228    0
# Name: Population, Length: 229, dtype: int32

# %%
data['Density']=np.where(data['Population density (per km2, 2017)']>100.0,1,0)      # 1 stands for >100, 0 stands for <100

# %%
data['Density']
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 224    0
# 225    0
# 226    0
# 227    0
# 228    0
# Name: Density, Length: 229, dtype: int32

# %%
data['Count']=1

# %%
data_new=data[['Population','Density','Count']]

# %%
data_new
# Out:
#      Population  Density  Count
# 0             0        0      1
# 1             0        1      1
# 2             0        0      1
# 3             0        1      1
# 4             0        1      1
# ..          ...      ...    ...
# 224           0        0      1
# 225           0        0      1
# 226           0        0      1
# 227           0        0      1
# 228           0        0      1
#
# [229 rows x 3 columns]

# %%
pd.pivot_table(data_new,values='Count', index=['Population'], columns=['Density'],aggfunc=np.size, fill_value=0)
# Out:
# Density       0   1
# Population
# 0           113  89
# 1            10  17

# %%
# A is the event where Population>50000
# B is the event where Pop_Density>=100 
p_A=10+17/113+89+10+17
p_B=89+17/113+89+10+17
p_A_B=17/113+89+10+17

# %%
result=p_A_B/p_B     #  P(A/B) = P(A_B)/P(B) = p_A_B/p_B

# %%
result
# Out:
# 0.566172030023294
